# %%
import numpy as np
from numpy import random
from scipy import stats
import matplotlib.pyplot as plt

# 10 random draws from a standard Gaussian distribution - N(0,1)
samples = random.randn(10)
# Gaussian distribution PDF with mean of 4 and standard deviation of 0.5
x = np.linspace(0, 8, 100)
pdf = stats.norm.pdf(x, loc=4, scale=0.5)

# %%
plt.plot(x, pdf, label='PDF')
# Out:
# array([-1.45472491,  0.76042629,  1.58505438, -0.35010613, -2.46650644,
#         0.03353111,  0.22359797, -1.77018229,  0.06403355, -1.27302474])
